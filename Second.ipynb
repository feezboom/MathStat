# %%
# %pylab inline

import numpy as np
import matplotlib.pyplot as plt

def addPlot(k, N, theta) :
    #Генерируем выборку.
    X = sts.expon.rvs(size=N, loc=0, scale=theta)
    result = []
    ourSum = 0.0
    for i in range(0, N) :
        ourSum += X[i]**k
        ourMean = ourSum / (i + 1)
        result.append(abs((math.factorial(k) / (ourMean))**(1/k)) - theta);

    if (k%5 == 0) :
        ourColor = 'red'
    elif (k%5 == 1) :
        ourColor = 'green';
    elif (k%5 == 2) :
        ourColor = 'blue'
    elif (k%5 == 3) :
        ourColor = 'magenta';
    elif (k%5 == 4) :
        ourColor = 'orange';
    plt.plot(np.arange(1, N + 1), result, color=ourColor, label='k = ' + str(k));
    
N = 10000;
theta = 1;
for start in range(1,21,5) :
    plt.figure(figsize=(25,20))
    for k in range(start,start+5,1) :
        addPlot(k, N, theta);
    plt.title('estimation that depends on n and k', fontsize = 50);
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.6), fontsize = 30)
    plt.ylabel('$|\\theta - \\theta^*(n)|$', fontsize = 50);
    plt.xlabel('n', fontsize = 50)
    plt.ylim(0, theta/1.5);
    plt.xlim(1000, 10000);
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Если приглядеться, то несложно заметить, что для меньших k отклонение оценки от реальной ниже, чем у больших k.
#
# # Следовательно, можно сделать вывод о том, что меньшие k дают более  эффективную оценку
